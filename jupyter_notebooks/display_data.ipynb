# %% [markdown]
# # Display Data
# ---

# %% [markdown]
# # Change working directory

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/stephenbeese/GitHub/Video-Game-Sales-Analysis/jupyter_notebooks'

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/stephenbeese/GitHub/Video-Game-Sales-Analysis'

# %% [markdown]
# Set up the data directories

# %%
# Set the file path for the raw data
raw_data_dir = os.path.join(current_dir, 'data/raw')

# Set the file path for the processed data
processed_data_dir = os.path.join(current_dir, 'data/processed')

# Print file paths
print("Raw data directory:", raw_data_dir)
print("Processed data directory:", processed_data_dir)
# Out:
# Raw data directory: /Users/stephenbeese/GitHub/Video-Game-Sales-Analysis/data/raw
# Processed data directory: /Users/stephenbeese/GitHub/Video-Game-Sales-Analysis/data/processed

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Load the csv files into dataframes

# %%
df_master = pd.read_csv(os.path.join(processed_data_dir, 'video_game_sales_cleaned.csv'))
df_merged = pd.read_csv(os.path.join(processed_data_dir, 'video_game_sales_merged.csv'))
df_first_party = pd.read_csv(os.path.join(processed_data_dir, 'video_game_sales_first_party.csv'))
df_critic_reviews = pd.read_csv(os.path.join(processed_data_dir, 'video_game_sales_critic_review.csv'))
df_user_reviews = pd.read_csv(os.path.join(processed_data_dir, 'video_game_sales_user_review.csv'))

# %% [markdown]
# ---
# # ``video_game_sales_cleaned.csv``

# %%
df_master
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16712  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16713               LMA Manager 2007     X360             2006        Sports
# 16714        Haitaka no Psychedelica      PSV             2016     Adventure
# 16715               Spirits & Spells      GBA             2003      Platform
# 16716            Winning Post 8 2016      PSV             2016    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16712    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16713   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16714  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16715       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16716    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#       Developer
# 0      Nintendo
# 1       Unknown
# 2      Nintendo
# 3      Nintendo
# 4       Unknown
# ...         ...
# 16712   Unknown
# 16713   Unknown
# 16714   Unknown
# 16715   Unknown
# 16716   Unknown
#
# [16717 rows x 11 columns]

# %% [markdown]
# ---
# # ``video_game_sales_merged.csv``

# %%
df_merged
# Out:
#                                  Name  Year_of_Release  \
# 0                          Wii Sports           2006.0
# 1                  Grand Theft Auto V           2013.0
# 2                   Super Mario Bros.           1985.0
# 3                              Tetris           1988.0
# 4                      Mario Kart Wii           2008.0
# ...                               ...              ...
# 11897                 Cross Edge Dash           2009.0
# 11898                Crossroad Crisis           2000.0
# 11899             Crows: Burning Edge           2016.0
# 11900  Curse of the Amsterdam Diamond           2012.0
# 11901        Mezase!! Tsuri Master DS           2009.0
#
#                        Platform         Genre             Publisher  \
# 0                           Wii        Sports              Nintendo
# 1      PC, PS3, PS4, X360, XOne        Action  Take-Two Interactive
# 2                           NES      Platform              Nintendo
# 3                       GB, NES        Puzzle              Nintendo
# 4                           Wii        Racing              Nintendo
# ...                         ...           ...                   ...
# 11897                      X360  Role-Playing         Compile Heart
# 11898                        PS        Puzzle               Success
# 11899                       PS4        Action    Namco Bandai Games
# 11900                        DS        Puzzle      Easy Interactive
# 11901                        DS        Sports           Hudson Soft
#
#             Developer  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0            Nintendo     41.36     28.96      3.77         8.45
# 1      Rockstar North     23.84     23.42      1.42         7.90
# 2                 NaN     29.08      3.58      6.81         0.77
# 3                 NaN     26.17      2.95      6.03         0.69
# 4            Nintendo     15.68     12.76      3.79         3.29
# ...               ...       ...       ...       ...          ...
# 11897   Compile Heart      0.00      0.00      0.01         0.00
# 11898             NaN      0.01      0.00      0.00         0.00
# 11899             NaN      0.00      0.00      0.01         0.00
# 11900             NaN      0.00      0.01      0.00         0.00
# 11901             NaN      0.00      0.00      0.01         0.00
#
#        Global_Sales  is_multiplatform
# 0             82.53             False
# 1             56.57              True
# 2             40.24             False
# 3             35.84              True
# 4             35.52             False
# ...             ...               ...
# 11897          0.01             False
# 11898          0.01             False
# 11899          0.01             False
# 11900          0.01             False
# 11901          0.01             False
#
# [11902 rows x 12 columns]

# %% [markdown]
# ---
# # ``video_game_sales_first_party.csv``

# %%
df_first_party
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16712  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16713               LMA Manager 2007     X360             2006        Sports
# 16714        Haitaka no Psychedelica      PSV             2016     Adventure
# 16715               Spirits & Spells      GBA             2003      Platform
# 16716            Winning Post 8 2016      PSV             2016    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16712    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16713   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16714  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16715       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16716    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#       Developer  is_first_party
# 0      Nintendo            True
# 1       Unknown            True
# 2      Nintendo            True
# 3      Nintendo            True
# 4       Unknown            True
# ...         ...             ...
# 16712   Unknown           False
# 16713   Unknown           False
# 16714   Unknown           False
# 16715   Unknown           False
# 16716   Unknown           False
#
# [16717 rows x 12 columns]

# %% [markdown]
# ---
# # ``video_game_sales_critic_review.csv``

# %%
df_critic_reviews
# Out:
#                          Name Platform  Year_of_Release      Genre  \
# 0                  Wii Sports      Wii           2006.0     Sports
# 1              Mario Kart Wii      Wii           2008.0     Racing
# 2           Wii Sports Resort      Wii           2009.0     Sports
# 3       New Super Mario Bros.       DS           2006.0   Platform
# 4                    Wii Play      Wii           2006.0       Misc
# ...                       ...      ...              ...        ...
# 8132                   Breach       PC           2011.0    Shooter
# 8133         Bust-A-Move 3000       GC           2003.0     Puzzle
# 8134         Mega Brain Boost       DS           2008.0     Puzzle
# 8135  STORM: Frontline Nation       PC           2011.0   Strategy
# 8136                  15 Days       PC           2009.0  Adventure
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                  Nintendo     41.36     28.96      3.77         8.45
# 1                  Nintendo     15.68     12.76      3.79         3.29
# 2                  Nintendo     15.61     10.93      3.28         2.95
# 3                  Nintendo     11.28      9.14      6.50         2.88
# 4                  Nintendo     13.96      9.18      2.93         2.84
# ...                     ...       ...       ...       ...          ...
# 8132              Destineer      0.01      0.00      0.00         0.00
# 8133                Ubisoft      0.01      0.00      0.00         0.00
# 8134  Majesco Entertainment      0.01      0.00      0.00         0.00
# 8135                Unknown      0.00      0.01      0.00         0.00
# 8136      DTP Entertainment      0.00      0.01      0.00         0.00
#
#       Global_Sales  Critic_Score  Critic_Count           Developer
# 0            82.53            76          51.0            Nintendo
# 1            35.52            82          73.0            Nintendo
# 2            32.77            80          73.0            Nintendo
# 3            29.80            89          65.0            Nintendo
# 4            28.92            58          41.0            Nintendo
# ...            ...           ...           ...                 ...
# 8132          0.01            61          12.0        Atomic Games
# 8133          0.01            53           4.0   Taito Corporation
# 8134          0.01            48          10.0  Interchannel-Holon
# 8135          0.01            60          12.0              SimBin
# 8136          0.01            63           6.0   DTP Entertainment
#
# [8137 rows x 13 columns]

# %% [markdown]
# ---
# # ``video_game_sales_user_review.csv``

# %%
df_user_reviews
# Out:
#                                    Name Platform  Year_of_Release      Genre  \
# 0                            Wii Sports      Wii           2006.0     Sports
# 1                        Mario Kart Wii      Wii           2008.0     Racing
# 2                     Wii Sports Resort      Wii           2009.0     Sports
# 3                 New Super Mario Bros.       DS           2006.0   Platform
# 4                              Wii Play      Wii           2006.0       Misc
# ...                                 ...      ...              ...        ...
# 7585                            Worms 2       PC           1997.0   Strategy
# 7586  Metal Gear Solid V: Ground Zeroes       PC           2014.0     Action
# 7587                             Breach       PC           2011.0    Shooter
# 7588            STORM: Frontline Nation       PC           2011.0   Strategy
# 7589                            15 Days       PC           2009.0  Adventure
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                         Nintendo     41.36     28.96      3.77         8.45
# 1                         Nintendo     15.68     12.76      3.79         3.29
# 2                         Nintendo     15.61     10.93      3.28         2.95
# 3                         Nintendo     11.28      9.14      6.50         2.88
# 4                         Nintendo     13.96      9.18      2.93         2.84
# ...                            ...       ...       ...       ...          ...
# 7585                    Microprose      0.00      0.01      0.00         0.00
# 7586  Konami Digital Entertainment      0.00      0.01      0.00         0.00
# 7587                     Destineer      0.01      0.00      0.00         0.00
# 7588                       Unknown      0.00      0.01      0.00         0.00
# 7589             DTP Entertainment      0.00      0.01      0.00         0.00
#
#       Global_Sales  User_Score  User_Count           Developer
# 0            82.53         8.0       322.0            Nintendo
# 1            35.52         8.3       709.0            Nintendo
# 2            32.77         8.0       192.0            Nintendo
# 3            29.80         8.5       431.0            Nintendo
# 4            28.92         6.6       129.0            Nintendo
# ...            ...         ...         ...                 ...
# 7585          0.01         8.1        12.0             Team 17
# 7586          0.01         7.6       412.0  Kojima Productions
# 7587          0.01         5.8        43.0        Atomic Games
# 7588          0.01         7.2        13.0              SimBin
# 7589          0.01         5.8         8.0   DTP Entertainment
#
# [7590 rows x 13 columns]

# %% [markdown]
# ---
